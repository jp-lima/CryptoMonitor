# %%
import pandas as pd; 
from pesquisa_binaria import pesquisa_de_criptomoedas

dataframe_das_criptomoedas = pd.read_csv('cripto_em_ordem_alfabetica.csv')
df_copia = dataframe_das_criptomoedas

pesquisa_usuario = 'i'.lower()

# %%
resultado_pesquisa = pesquisa_de_criptomoedas(df_copia, pesquisa_usuario )

display(resultado_pesquisa)
# Out:
#                                Moeda  ...                FDV
# 0               A Hunters Dream  CAW  ...     US$ 32.513.215
# 1                         Aave  AAVE  ...  US$ 2.767.607.136
# 2                   Aavegotchi  GHST  ...     US$ 27.947.559
# 3                     Abster  ABSTER  ...     US$ 10.473.211
# 4                         aBTC  ABTC  ...    US$ 239.092.018
# ...                              ...  ...                ...
# 1798                      1GUY  1GUY  ...      US$ 6.179.639
# 1799                    1inch  1INCH  ...    US$ 307.157.862
# 1800                0x Protocol  ZRX  ...    US$ 282.332.146
# 1801  0x0.ai: AI Smart Contract  0X0  ...     US$ 73.448.403
# 1802         $HYPERSKIDS  HYPERSKIDS  ...      US$ 9.152.831
#
# [1803 rows x 5 columns]
